# %% [markdown]
# # Testing procedure: STARR

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
os.chdir('/share/pi/boussard/eroosli_work/benchmarking')
import sys
if sys.version_info[0] == 3:
    from importlib import reload
import warnings
warnings.filterwarnings('ignore')

from models.common_utils import optimal_epoch

# %% [markdown]
# ## A) Find optimal epoch

# %%
optimal_epoch('2020-04-08_15-25.k_clstms.none.csv', 'mimic')
# Out:
# 32

# %% [markdown]
# ## B) Predictions on test data

# %%
# %run models/ihm/main.py --network models/keras_models/channel_wise_lstms.py \
--data data/starr/ihm  --output_dir models/outputs/starr \
--mask_demographics "Gender" "Ethnicity" "Insurance" --validating\
--dim 8 --depth 1 --batch_size 8 --dropout 0.3 --timestep 1.0 \
--load_state models/outputs/mimic/keras_states/2020-04-08_15-25_/2020-04-08_15-25_k_channel_wise_lstms_aug.n8.szc4.0.d0.3.dep1.bs8.ts1.0.epoch32.test0.28141715225643954.state \
--mode test --size_coef 4.0
# Out:
# normalizer state: /share/pi/boussard/eroosli_work/benchmarking/models/ihm/ihm_ts1.0.input_str_previous.start_time_zero.normalizer
# ==> using model models/keras_models/channel_wise_lstms.py
# ==> not used params in network class: dict_keys(['batch_size', 'beta_1', 'data', 'data_name', 'epochs', 'imputation', 'l1', 'l2', 'load_state', 'lr', 'mode', 'network', 'normalizer_state', 'optimizer', 'output_dir', 'prefix', 'save_every', 'small_part', 'target_repl_coef', 'timestep', 'validating', 'verbose'])
# ==> excluded demographics: ['Gender', 'Ethnicity', 'Insurance']
# ==> found 17 channels: ['Capillary refill rate', 'Diastolic blood pressure', 'Fraction inspired oxygen', 'Glascow coma scale eye opening', 'Glascow coma scale motor response', 'Glascow coma scale total', 'Glascow coma scale verbal response', 'Glucose', 'Heart rate', 'Height', 'Mean blood pressure', 'Oxygen saturation', 'Respiratory rate', 'Systolic blood pressure', 'Temperature', 'Weight', 'pH']
# ==> model.final_name: 2020-06-04_12-14.k_clstms.NONE
# ==> compiling the model
# Model: "network_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# X (InputLayer)                  (None, None, 76)     0
# __________________________________________________________________________________________________
# masking_4 (Masking)             (None, None, 76)     0           X[0][0]
# __________________________________________________________________________________________________
# slice_52 (Slice)                (None, None, 3)      0           masking_4[0][0]
# __________________________________________________________________________________________________
# slice_53 (Slice)                (None, None, 2)      0           masking_4[0][0]
# __________________________________________________________________________________________________
# slice_54 (Slice)                (None, None, 2)      0           masking_4[0][0]
# __________________________________________________________________________________________________
# slice_55 (Slice)                (None, None, 9)      0           masking_4[0][0]
# __________________________________________________________________________________________________
# slice_56 (Slice)                (None, None, 13)     0           masking_4[0][0]
# __________________________________________________________________________________________________
# slice_57 (Slice)                (None, None, 14)     0           masking_4[0][0]
# __________________________________________________________________________________________________
# slice_58 (Slice)                (None, None, 13)     0           masking_4[0][0]
# __________________________________________________________________________________________________
# slice_59 (Slice)                (None, None, 2)      0           masking_4[0][0]
# __________________________________________________________________________________________________
# slice_60 (Slice)                (None, None, 2)      0           masking_4[0][0]
# __________________________________________________________________________________________________
# slice_61 (Slice)                (None, None, 2)      0           masking_4[0][0]
# __________________________________________________________________________________________________
# slice_62 (Slice)                (None, None, 2)      0           masking_4[0][0]
# __________________________________________________________________________________________________
# slice_63 (Slice)                (None, None, 2)      0           masking_4[0][0]
# __________________________________________________________________________________________________
# slice_64 (Slice)                (None, None, 2)      0           masking_4[0][0]
# __________________________________________________________________________________________________
# slice_65 (Slice)                (None, None, 2)      0           masking_4[0][0]
# __________________________________________________________________________________________________
# slice_66 (Slice)                (None, None, 2)      0           masking_4[0][0]
# __________________________________________________________________________________________________
# slice_67 (Slice)                (None, None, 2)      0           masking_4[0][0]
# __________________________________________________________________________________________________
# slice_68 (Slice)                (None, None, 2)      0           masking_4[0][0]
# __________________________________________________________________________________________________
# bidirectional_52 (Bidirectional (None, None, 8)      256         slice_52[0][0]
# __________________________________________________________________________________________________
# bidirectional_53 (Bidirectional (None, None, 8)      224         slice_53[0][0]
# __________________________________________________________________________________________________
# bidirectional_54 (Bidirectional (None, None, 8)      224         slice_54[0][0]
# __________________________________________________________________________________________________
# bidirectional_55 (Bidirectional (None, None, 8)      448         slice_55[0][0]
# __________________________________________________________________________________________________
# bidirectional_56 (Bidirectional (None, None, 8)      576         slice_56[0][0]
# __________________________________________________________________________________________________
# bidirectional_57 (Bidirectional (None, None, 8)      608         slice_57[0][0]
# __________________________________________________________________________________________________
# bidirectional_58 (Bidirectional (None, None, 8)      576         slice_58[0][0]
# __________________________________________________________________________________________________
# bidirectional_59 (Bidirectional (None, None, 8)      224         slice_59[0][0]
# __________________________________________________________________________________________________
# bidirectional_60 (Bidirectional (None, None, 8)      224         slice_60[0][0]
# __________________________________________________________________________________________________
# bidirectional_61 (Bidirectional (None, None, 8)      224         slice_61[0][0]
# __________________________________________________________________________________________________
# bidirectional_62 (Bidirectional (None, None, 8)      224         slice_62[0][0]
# __________________________________________________________________________________________________
# bidirectional_63 (Bidirectional (None, None, 8)      224         slice_63[0][0]
# __________________________________________________________________________________________________
# bidirectional_64 (Bidirectional (None, None, 8)      224         slice_64[0][0]
# __________________________________________________________________________________________________
# bidirectional_65 (Bidirectional (None, None, 8)      224         slice_65[0][0]
# __________________________________________________________________________________________________
# bidirectional_66 (Bidirectional (None, None, 8)      224         slice_66[0][0]
# __________________________________________________________________________________________________
# bidirectional_67 (Bidirectional (None, None, 8)      224         slice_67[0][0]
# __________________________________________________________________________________________________
# bidirectional_68 (Bidirectional (None, None, 8)      224         slice_68[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, None, 136)    0           bidirectional_52[0][0]
#                                                                  bidirectional_53[0][0]
#                                                                  bidirectional_54[0][0]
#                                                                  bidirectional_55[0][0]
#                                                                  bidirectional_56[0][0]
#                                                                  bidirectional_57[0][0]
#                                                                  bidirectional_58[0][0]
#                                                                  bidirectional_59[0][0]
#                                                                  bidirectional_60[0][0]
#                                                                  bidirectional_61[0][0]
#                                                                  bidirectional_62[0][0]
#                                                                  bidirectional_63[0][0]
#                                                                  bidirectional_64[0][0]
#                                                                  bidirectional_65[0][0]
#                                                                  bidirectional_66[0][0]
#                                                                  bidirectional_67[0][0]
#                                                                  bidirectional_68[0][0]
# __________________________________________________________________________________________________
# lstm_72 (LSTM)                  (None, 32)           21632       concatenate_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 32)           0           lstm_72[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            33          dropout_4[0][0]
# ==================================================================================================
# Total params: 26,817
# Trainable params: 26,817
# Non-trainable params: 0
# __________________________________________________________________________________________________
# models/outputs/mimic/keras_states/2020-04-08_15-25_/2020-04-08_15-25_k_channel_wise_lstms_aug.n8.szc4.0.d0.3.dep1.bs8.ts1.0.epoch32.test0.28141715225643954.state
# 6407/6407 [==============================] - 95s 15ms/step
#
# confusion matrix:
# [[2950   21]
#  [ 291   59]]
#
# stratified metric for:
# demographic variable: Insurance
# value: Medicare
#
# overall metrics:
# prevalence of IHM = 0.10539
# average predicted risk of IHM = 0.06572499871253967
# difference in average predicted and observed risk = -0.039665001287460325
# number samples = 3321
# accuracy = 0.906052
# precision class 0 = 0.910213
# precision class 1 = 0.7375
# recall class 0 = 0.992932
# recall class 1 = 0.168571
# false negative rate = 0.831429
# false positive rate = 0.007068
# positive prediction rate = 0.024089
# AUC of ROC = 0.809572
# AUC of PRC = 0.419501
# min(+P, Se) = 0.425714
#
# -------------------------------
#
# confusion matrix:
# [[887  15]
#  [ 82  22]]
#
# stratified metric for:
# demographic variable: Insurance
# value: Medicaid
#
# overall metrics:
# prevalence of IHM = 0.10338
# average predicted risk of IHM = 0.08152800053358078
# difference in average predicted and observed risk = -0.02185199946641922
# number samples = 1006
# accuracy = 0.903579
# precision class 0 = 0.915377
# precision class 1 = 0.594595
# recall class 0 = 0.98337
# recall class 1 = 0.211538
# false negative rate = 0.788462
# false positive rate = 0.01663
# positive prediction rate = 0.036779
# AUC of ROC = 0.823491
# AUC of PRC = 0.395371
# min(+P, Se) = 0.396226
#
# -------------------------------
#
# confusion matrix:
# [[1611   25]
#  [ 134   30]]
#
# stratified metric for:
# demographic variable: Insurance
# value: Private
#
# overall metrics:
# prevalence of IHM = 0.091111
# average predicted risk of IHM = 0.06919000297784805
# difference in average predicted and observed risk = -0.021920997022151945
# number samples = 1800
# accuracy = 0.911667
# precision class 0 = 0.923209
# precision class 1 = 0.545455
# recall class 0 = 0.984719
# recall class 1 = 0.182927
# false negative rate = 0.817073
# false positive rate = 0.015281
# positive prediction rate = 0.030556
# AUC of ROC = 0.845343
# AUC of PRC = 0.362007
# min(+P, Se) = 0.420732
#
# -------------------------------
#
# confusion matrix:
# [[244   2]
#  [ 24  10]]
#
# stratified metric for:
# demographic variable: Insurance
# value: Other
#
# overall metrics:
# prevalence of IHM = 0.121429
# average predicted risk of IHM = 0.07705900073051453
# difference in average predicted and observed risk = -0.04436999926948547
# number samples = 280
# accuracy = 0.907143
# precision class 0 = 0.910448
# precision class 1 = 0.833333
# recall class 0 = 0.99187
# recall class 1 = 0.294118
# false negative rate = 0.705882
# false positive rate = 0.00813
# positive prediction rate = 0.042857
# AUC of ROC = 0.915232
# AUC of PRC = 0.676178
# min(+P, Se) = 0.676471
#
# -------------------------------
#
# confusion matrix:
# [[3384   36]
#  [ 279   67]]
#
# stratified metric for:
# demographic variable: Gender
# value: M
#
# overall metrics:
# prevalence of IHM = 0.091875
# average predicted risk of IHM = 0.06355399638414383
# difference in average predicted and observed risk = -0.02832100361585617
# number samples = 3766
# accuracy = 0.916357
# precision class 0 = 0.923833
# precision class 1 = 0.650485
# recall class 0 = 0.989474
# recall class 1 = 0.193642
# false negative rate = 0.806358
# false positive rate = 0.010526
# positive prediction rate = 0.02735
# AUC of ROC = 0.832174
# AUC of PRC = 0.393923
# min(+P, Se) = 0.411268
#
# -------------------------------
#
# confusion matrix:
# [[2308   27]
#  [ 252   54]]
#
# stratified metric for:
# demographic variable: Gender
# value: F
#
# overall metrics:
# prevalence of IHM = 0.115865
# average predicted risk of IHM = 0.07840300351381302
# difference in average predicted and observed risk = -0.03746199648618698
# number samples = 2641
# accuracy = 0.894358
# precision class 0 = 0.901563
# precision class 1 = 0.666667
# recall class 0 = 0.988437
# recall class 1 = 0.176471
# false negative rate = 0.823529
# false positive rate = 0.011563
# positive prediction rate = 0.03067
# AUC of ROC = 0.817271
# AUC of PRC = 0.422731
# min(+P, Se) = 0.462541
#
# -------------------------------
#
# confusion matrix:
# [[3055   15]
#  [ 251   40]]
#
# stratified metric for:
# demographic variable: Ethnicity
# value: WHITE
#
# overall metrics:
# prevalence of IHM = 0.086581
# average predicted risk of IHM = 0.05562499910593033
# difference in average predicted and observed risk = -0.030956000894069677
# number samples = 3361
# accuracy = 0.920857
# precision class 0 = 0.924077
# precision class 1 = 0.727273
# recall class 0 = 0.995114
# recall class 1 = 0.137457
# false negative rate = 0.862543
# false positive rate = 0.004886
# positive prediction rate = 0.016364
# AUC of ROC = 0.817434
# AUC of PRC = 0.374278
# min(+P, Se) = 0.375796
#
# -------------------------------
#
# confusion matrix:
# [[767  11]
#  [ 86  19]]
#
# stratified metric for:
# demographic variable: Ethnicity
# value: ASIAN
#
# overall metrics:
# prevalence of IHM = 0.118913
# average predicted risk of IHM = 0.0835070013999939
# difference in average predicted and observed risk = -0.03540599860000611
# number samples = 883
# accuracy = 0.890147
# precision class 0 = 0.899179
# precision class 1 = 0.633333
# recall class 0 = 0.985861
# recall class 1 = 0.180952
# false negative rate = 0.819048
# false positive rate = 0.014139
# positive prediction rate = 0.033975
# AUC of ROC = 0.844277
# AUC of PRC = 0.436251
# min(+P, Se) = 0.471698
#
# -------------------------------
#
# confusion matrix:
# [[673  14]
#  [ 80  27]]
#
# stratified metric for:
# demographic variable: Ethnicity
# value: OTHER
#
# overall metrics:
# prevalence of IHM = 0.134761
# average predicted risk of IHM = 0.0899759978055954
# difference in average predicted and observed risk = -0.044785002194404594
# number samples = 794
# accuracy = 0.881612
# precision class 0 = 0.893758
# precision class 1 = 0.658537
# recall class 0 = 0.979622
# recall class 1 = 0.252336
# false negative rate = 0.747664
# false positive rate = 0.020378
# positive prediction rate = 0.051637
# AUC of ROC = 0.837353
# AUC of PRC = 0.475994
# min(+P, Se) = 0.495726
#
# -------------------------------
#
# confusion matrix:
# [[883  16]
#  [ 86  30]]
#
# stratified metric for:
# demographic variable: Ethnicity
# value: HISPANIC
#
# overall metrics:
# prevalence of IHM = 0.114286
# average predicted risk of IHM = 0.0885239988565445
# difference in average predicted and observed risk = -0.025762001143455504
# number samples = 1015
# accuracy = 0.899507
# precision class 0 = 0.911249
# precision class 1 = 0.652174
# recall class 0 = 0.982202
# recall class 1 = 0.258621
# false negative rate = 0.741379
# false positive rate = 0.017798
# positive prediction rate = 0.04532
# AUC of ROC = 0.841692
# AUC of PRC = 0.466491
# min(+P, Se) = 0.495868
#
# -------------------------------
#
# confusion matrix:
# [[314   7]
#  [ 28   5]]
#
# stratified metric for:
# demographic variable: Ethnicity
# value: BLACK
#
# overall metrics:
# prevalence of IHM = 0.09322
# average predicted risk of IHM = 0.06899499893188477
# difference in average predicted and observed risk = -0.02422500106811523
# number samples = 354
# accuracy = 0.90113
# precision class 0 = 0.918129
# precision class 1 = 0.416667
# recall class 0 = 0.978193
# recall class 1 = 0.151515
# false negative rate = 0.848485
# false positive rate = 0.021807
# positive prediction rate = 0.033898
# AUC of ROC = 0.739356
# AUC of PRC = 0.239018
# min(+P, Se) = 0.30303
#
# -------------------------------
#
# confusion matrix:
# [[3837   36]
#  [ 373   81]]
#
# stratified metric for:
# demographic variable: binaryIns
# value: Public
#
# overall metrics:
# prevalence of IHM = 0.104923
# average predicted risk of IHM = 0.06939899921417236
# difference in average predicted and observed risk = -0.03552400078582764
# number samples = 4327
# accuracy = 0.905477
# precision class 0 = 0.911401
# precision class 1 = 0.692308
# recall class 0 = 0.990705
# recall class 1 = 0.178414
# false negative rate = 0.821586
# false positive rate = 0.009295
# positive prediction rate = 0.02704
# AUC of ROC = 0.812485
# AUC of PRC = 0.409541
# min(+P, Se) = 0.419565
#
# -------------------------------
#
# confusion matrix:
# [[1611   25]
#  [ 134   30]]
#
# stratified metric for:
# demographic variable: binaryIns
# value: Private
#
# overall metrics:
# prevalence of IHM = 0.091111
# average predicted risk of IHM = 0.06919000297784805
# difference in average predicted and observed risk = -0.021920997022151945
# number samples = 1800
# accuracy = 0.911667
# precision class 0 = 0.923209
# precision class 1 = 0.545455
# recall class 0 = 0.984719
# recall class 1 = 0.182927
# false negative rate = 0.817073
# false positive rate = 0.015281
# positive prediction rate = 0.030556
# AUC of ROC = 0.845343
# AUC of PRC = 0.362007
# min(+P, Se) = 0.420732
#
# -------------------------------
#
# confusion matrix:
# [[244   2]
#  [ 24  10]]
#
# stratified metric for:
# demographic variable: binaryIns
# value: Selfpay
#
# overall metrics:
# prevalence of IHM = 0.121429
# average predicted risk of IHM = 0.07705900073051453
# difference in average predicted and observed risk = -0.04436999926948547
# number samples = 280
# accuracy = 0.907143
# precision class 0 = 0.910448
# precision class 1 = 0.833333
# recall class 0 = 0.99187
# recall class 1 = 0.294118
# false negative rate = 0.705882
# false positive rate = 0.00813
# positive prediction rate = 0.042857
# AUC of ROC = 0.915232
# AUC of PRC = 0.676178
# min(+P, Se) = 0.676471
#
# -------------------------------
#
# confusion matrix:
# [[5692   63]
#  [ 531  121]]
# prevalence of IHM = 0.101764
# average predicted risk of IHM = 0.06967499852180481
# difference in average predicted and observed risk = -0.032089001478195184
# number samples = 6407
# accuracy = 0.907289
# precision class 0 = 0.914671
# precision class 1 = 0.657609
# recall class 0 = 0.989053
# recall class 1 = 0.185583
# false negative rate = 0.814417
# false positive rate = 0.010947
# positive prediction rate = 0.028719
# AUC of ROC = 0.82662
# AUC of PRC = 0.40701
# min(+P, Se) = 0.432061
#
# -------------------------------

# %% [markdown]
# ## C) Evaluate test predictions

# %%
# %run models/evaluation/evaluate_ihm.py 'models/outputs/starr_ext/predictions/results/TEST.2020-06-04_12-14.k_clstms.NONE.csv' \
--n_iters 10000 --test_listfile 'data/starr/ihm/listfile.csv' --output_dir 'models/outputs/starr_ext/predictions/confvals' --stratify
# Out:
# Saving the results in models/outputs/starr/predictions/confvals/ext_validation/2020-06-04_12-43.stratified_ihm_results.json ...

# %%
# %run models/evaluation/evaluate_ihm.py 'models/outputs/starr_ext/predictions/results/TEST.2020-06-04_12-14.k_clstms.NONE.csv' \
--n_iters 10000 --test_listfile 'data/starr/ihm/listfile.csv' --output_dir 'models/outputs/starr_ext/predictions/confvals'
# Out:
# Saving the results in models/outputs/starr/predictions/confvals/ext_validation/2020-06-04_13-1.nonstratified_ihm_results.json ...

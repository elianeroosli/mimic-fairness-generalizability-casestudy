# %% [markdown]
# # Preliminary analysis: MIMIC

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
os.chdir('/share/pi/boussard/eroosli_work/benchmarking')
import sys
if sys.version_info[0] == 3:
    from importlib import reload
import warnings
warnings.filterwarnings('ignore')

import models.evaluation.learningcurves as lc
import models.evaluation.calibration as cb
import models.evaluation.performance as pm

# %% [markdown]
# ## A) Load data

# %%
path_metrics = 'models/outputs/mimic/predictions/metrics/TEST.2020-04-22_14-11.k_clstms.none.csv'
metrics = pm.metrics_csv(path_metrics)

# %%
path_results = 'models/outputs/mimic/predictions/results/TEST.2020-04-22_14-11.k_clstms.none.csv'
results = cb.results_csv(path_results)

# %%
dir_curves = 'models/outputs/mimic/predictions/curves/TEST.2020-04-22_14-11.k_clstms.none'

# %% [markdown]
# ## B) Precision vs. Recall Plot

# %%
path_prc = os.path.join(dir_curves, "overall_overall_prc.csv")

# %%
pm.plot_cutoff(path_prc)

# %% [markdown]
# ## C) General analysis

# %%
pm.plot_roc_prc(dir_curves, "overall")

# %%
results_all = cb.risk_groups(results, 10)
cb.side_by_side_calibration([results_all], ["overall"])

# %% [markdown]
# ## D) Analysis by demographic groups

# %% [markdown]
# ### 1) Insurance

# %%
pm.plot_roc_prc(dir_curves, "Insurance")

# %%
results_ins, labels = cb.calibration_dem(results, "Insurance")
cb.side_by_side_calibration(results_ins, labels)

# %%
metrics_ins = pm.df_processing(metrics, 'Insurance')
pm.plot_metrics_basic(metrics_ins, 'Insurance')

# %% [markdown]
# ### Binary case: Public vs. Private

# %%
pm.plot_roc_prc(dir_curves, "binaryIns")

# %%
results_ins, labels = cb.calibration_dem(results, "binaryIns", g=10)
cb.side_by_side_calibration(results_ins, labels)

# %%
metrics_ins = pm.df_processing(metrics, 'binaryIns')
pm.plot_metrics_basic(metrics_ins, 'binaryIns')

# %% [markdown]
# ### 2) Gender

# %%
pm.plot_roc_prc(dir_curves, "Gender")

# %%
results_gen, labels = cb.calibration_dem(results, "Gender", g=8)
cb.side_by_side_calibration(results_gen, labels)

# %%
metrics_gen = pm.df_processing(metrics, 'Gender')
pm.plot_metrics_basic(metrics_gen, 'Gender')

# %% [markdown]
# ### 3) Ethnicity

# %%
pm.plot_roc_prc(dir_curves, "Ethnicity")

# %%
results_eth, labels = cb.calibration_dem(results, "Ethnicity")
cb.side_by_side_calibration(results_eth, labels)

# %%
metrics_eth = pm.df_processing(metrics, "Ethnicity")
pm.plot_metrics_basic(metrics_eth, "Ethnicity")

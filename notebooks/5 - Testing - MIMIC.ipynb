# %% [markdown]
# # Testing Procedure: MIMIC

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
os.chdir('/share/pi/boussard/eroosli_work/benchmarking')
import sys
if sys.version_info[0] == 3:
    from importlib import reload
import warnings
warnings.filterwarnings('ignore')
from imblearn.over_sampling import RandomOverSampler

from models.common_utils import optimal_epoch
from benchmarks import demographics as dm
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## A) Find best epoch from training

# %%
optimal_epoch('2020-04-08_15-25.k_clstms.none.csv', 'mimic')
# Out:
# 32

# %% [markdown]
# ## B) Predictions on test data

# %%
mimic_pat_test, mimic_stays_test = dm.mimic_cohort_demographics('data/mimic/aug/mortality', 'test')
# Out:
# chosen option: test
# EPISODE 3236 of 3236...

# %%
def get_ratios(df, variable):
    for group in df[variable].unique():
        df_group = df[df[variable]==group]
        y = df_group['IHM']
        print(y.sum(), y.sum()/(len(y)-y.sum()))

# %%
get_ratios(mimic_stays_test, 'ETHNICITY')
# Out:
# 64.0 0.17066666666666666
# 265.0 0.1281431334622824
# 28.0 0.10646387832699619
# 8.0 0.0784313725490196
# 9.0 0.16666666666666666

# %%
def equalizer(df, variable):
    ros = RandomOverSampler(sampling_strategy=0.22)

    frames = []
    for group in df[variable].unique():
        df_group = df[df[variable]==group]
        X = df_group[['CSV', 'ETHNICITY', 'IHM']]
        y = df_group['IHM']
        X_res, y_res = ros.fit_resample(X, y)
        print(y_res.sum(), y_res.sum()/(len(y_res)-y_res.sum()))
        frames.append(X_res)

    result = pd.concat(frames)
    result.rename(columns={'CSV': 'stay', 'IHM': 'y_true'}, inplace=True)
    result['y_true'] = result['y_true'].apply(lambda d: int(d))
    result[['stay', 'y_true']].to_csv(os.path.join('data/mimic/aug/mortality', variable + '_test_listfile.csv'), index=False)

# %%
equalizer(mimic_stays_test, 'ETHNICITY')
# Out:
# 71.0 0.18933333333333333
# 392.0 0.1895551257253385
# 49.0 0.18631178707224336
# 19.0 0.18627450980392157
# 10.0 0.18518518518518517

# %%
equalizer(mimic_stays_test, 'INSURANCE')
# Out:
# 205.0 0.21995708154506438
# 350.0 0.219435736677116
# 7.0 0.21875
# 48.0 0.21621621621621623
# 17.0 0.20987654320987653

# %%
ros = RandomOverSampler(sampling_strategy=0.19)

frames = []
for ethnicity in [1,2,3,4]:
    df = mimic_stays_test[mimic_stays_test['ETHNICITY']==ethnicity]
    X = df[['CSV', 'ETHNICITY', 'IHM']]
    y = df['IHM']
    X_res, y_res = ros.fit_resample(X, y)
    print(y_res.sum(), y_res.sum()/(len(y_res)-y_res.sum()))
    frames.append(X_res)

result = pd.concat(frames)

result.rename(columns={'CSV': 'stay', 'IHM': 'y_true'}, inplace=True)
result['y_true'] = result['y_true'].apply(lambda d: int(d))
result[['stay', 'y_true']].to_csv(os.path.join('data/mimic/aug/mortality', 'harmonized_test_listfile.csv'), index=False)

# %%
# %run models/ihm/main.py --network models/keras_models/channel_wise_lstms.py --mask_demographics "Ethnicity" "Gender" "Insurance" \
--data data/mimic/aug/mortality --data_name 'mimic' --dim 8 --depth 1 --batch_size 8 --dropout 0.3 --timestep 1.0 \
--load_state models/outputs/mimic/keras_states/2020-04-08_15-25_/2020-04-08_15-25_k_channel_wise_lstms_aug.n8.szc4.0.d0.3.dep1.bs8.ts1.0.epoch32.test0.28141715225643954.state --mode test --size_coef 4.0
# Out:
# normalizer state: /share/pi/boussard/eroosli_work/benchmarking/models/ihm/ihm_ts1.0.input_str_previous.start_time_zero.normalizer
# ==> using model models/keras_models/channel_wise_lstms.py
# ==> not used params in network class: dict_keys(['SMOTE', 'batch_size', 'beta_1', 'data', 'data_name', 'epochs', 'harmonizing', 'imputation', 'l1', 'l2', 'load_state', 'lr', 'mode', 'network', 'normalizer_state', 'optimizer', 'output_dir', 'prefix', 'save_every', 'small_part', 'target_repl_coef', 'timestep', 'validating', 'verbose'])
# ==> excluded demographics: ['Ethnicity', 'Gender', 'Insurance']
# ==> found 17 channels: ['Capillary refill rate', 'Diastolic blood pressure', 'Fraction inspired oxygen', 'Glascow coma scale eye opening', 'Glascow coma scale motor response', 'Glascow coma scale total', 'Glascow coma scale verbal response', 'Glucose', 'Heart rate', 'Height', 'Mean blood pressure', 'Oxygen saturation', 'Respiratory rate', 'Systolic blood pressure', 'Temperature', 'Weight', 'pH']
# ==> model.final_name: 2020-06-19_10-23.k_clstms.NONE
# ==> compiling the model
# Model: "network_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# X (InputLayer)                  (None, None, 76)     0
# __________________________________________________________________________________________________
# masking_3 (Masking)             (None, None, 76)     0           X[0][0]
# __________________________________________________________________________________________________
# slice_35 (Slice)                (None, None, 3)      0           masking_3[0][0]
# __________________________________________________________________________________________________
# slice_36 (Slice)                (None, None, 2)      0           masking_3[0][0]
# __________________________________________________________________________________________________
# slice_37 (Slice)                (None, None, 2)      0           masking_3[0][0]
# __________________________________________________________________________________________________
# slice_38 (Slice)                (None, None, 9)      0           masking_3[0][0]
# __________________________________________________________________________________________________
# slice_39 (Slice)                (None, None, 13)     0           masking_3[0][0]
# __________________________________________________________________________________________________
# slice_40 (Slice)                (None, None, 14)     0           masking_3[0][0]
# __________________________________________________________________________________________________
# slice_41 (Slice)                (None, None, 13)     0           masking_3[0][0]
# __________________________________________________________________________________________________
# slice_42 (Slice)                (None, None, 2)      0           masking_3[0][0]
# __________________________________________________________________________________________________
# slice_43 (Slice)                (None, None, 2)      0           masking_3[0][0]
# __________________________________________________________________________________________________
# slice_44 (Slice)                (None, None, 2)      0           masking_3[0][0]
# __________________________________________________________________________________________________
# slice_45 (Slice)                (None, None, 2)      0           masking_3[0][0]
# __________________________________________________________________________________________________
# slice_46 (Slice)                (None, None, 2)      0           masking_3[0][0]
# __________________________________________________________________________________________________
# slice_47 (Slice)                (None, None, 2)      0           masking_3[0][0]
# __________________________________________________________________________________________________
# slice_48 (Slice)                (None, None, 2)      0           masking_3[0][0]
# __________________________________________________________________________________________________
# slice_49 (Slice)                (None, None, 2)      0           masking_3[0][0]
# __________________________________________________________________________________________________
# slice_50 (Slice)                (None, None, 2)      0           masking_3[0][0]
# __________________________________________________________________________________________________
# slice_51 (Slice)                (None, None, 2)      0           masking_3[0][0]
# __________________________________________________________________________________________________
# bidirectional_35 (Bidirectional (None, None, 8)      256         slice_35[0][0]
# __________________________________________________________________________________________________
# bidirectional_36 (Bidirectional (None, None, 8)      224         slice_36[0][0]
# __________________________________________________________________________________________________
# bidirectional_37 (Bidirectional (None, None, 8)      224         slice_37[0][0]
# __________________________________________________________________________________________________
# bidirectional_38 (Bidirectional (None, None, 8)      448         slice_38[0][0]
# __________________________________________________________________________________________________
# bidirectional_39 (Bidirectional (None, None, 8)      576         slice_39[0][0]
# __________________________________________________________________________________________________
# bidirectional_40 (Bidirectional (None, None, 8)      608         slice_40[0][0]
# __________________________________________________________________________________________________
# bidirectional_41 (Bidirectional (None, None, 8)      576         slice_41[0][0]
# __________________________________________________________________________________________________
# bidirectional_42 (Bidirectional (None, None, 8)      224         slice_42[0][0]
# __________________________________________________________________________________________________
# bidirectional_43 (Bidirectional (None, None, 8)      224         slice_43[0][0]
# __________________________________________________________________________________________________
# bidirectional_44 (Bidirectional (None, None, 8)      224         slice_44[0][0]
# __________________________________________________________________________________________________
# bidirectional_45 (Bidirectional (None, None, 8)      224         slice_45[0][0]
# __________________________________________________________________________________________________
# bidirectional_46 (Bidirectional (None, None, 8)      224         slice_46[0][0]
# __________________________________________________________________________________________________
# bidirectional_47 (Bidirectional (None, None, 8)      224         slice_47[0][0]
# __________________________________________________________________________________________________
# bidirectional_48 (Bidirectional (None, None, 8)      224         slice_48[0][0]
# __________________________________________________________________________________________________
# bidirectional_49 (Bidirectional (None, None, 8)      224         slice_49[0][0]
# __________________________________________________________________________________________________
# bidirectional_50 (Bidirectional (None, None, 8)      224         slice_50[0][0]
# __________________________________________________________________________________________________
# bidirectional_51 (Bidirectional (None, None, 8)      224         slice_51[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, None, 136)    0           bidirectional_35[0][0]
#                                                                  bidirectional_36[0][0]
#                                                                  bidirectional_37[0][0]
#                                                                  bidirectional_38[0][0]
#                                                                  bidirectional_39[0][0]
#                                                                  bidirectional_40[0][0]
#                                                                  bidirectional_41[0][0]
#                                                                  bidirectional_42[0][0]
#                                                                  bidirectional_43[0][0]
#                                                                  bidirectional_44[0][0]
#                                                                  bidirectional_45[0][0]
#                                                                  bidirectional_46[0][0]
#                                                                  bidirectional_47[0][0]
#                                                                  bidirectional_48[0][0]
#                                                                  bidirectional_49[0][0]
#                                                                  bidirectional_50[0][0]
#                                                                  bidirectional_51[0][0]
# __________________________________________________________________________________________________
# lstm_54 (LSTM)                  (None, 32)           21632       concatenate_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 32)           0           lstm_54[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            33          dropout_3[0][0]
# ==================================================================================================
# Total params: 26,817
# Trainable params: 26,817
# Non-trainable params: 0
# __________________________________________________________________________________________________
# models/outputs/mimic/keras_states/2020-04-08_15-25_/2020-04-08_15-25_k_channel_wise_lstms_aug.n8.szc4.0.d0.3.dep1.bs8.ts1.0.epoch32.test0.28141715225643954.state
# 3489/3489 [==============================] - 51s 15ms/step
#
# confusion matrix:
# [[937  18]
#  [153  55]]
#
# stratified metric for:
# demographic variable: Insurance
# value: Private
#
# overall metrics:
# prevalence of IHM = 0.178848
# average predicted risk of IHM = 0.1136149987578392
# difference in average predicted and observed risk = -0.0652330012421608
# number samples = 1163
# accuracy = 0.852966
# precision class 0 = 0.859633
# precision class 1 = 0.753425
# recall class 0 = 0.981152
# recall class 1 = 0.264423
# false negative rate = 0.735577
# false positive rate = 0.018848
# positive prediction rate = 0.062769
# AUC of ROC = 0.891054
# AUC of PRC = 0.672552
# min(+P, Se) = 0.629808
#
# -------------------------------
#
# confusion matrix:
# [[1517   32]
#  [ 269   72]]
#
# stratified metric for:
# demographic variable: Insurance
# value: Medicare
#
# overall metrics:
# prevalence of IHM = 0.180423
# average predicted risk of IHM = 0.12037800252437592
# difference in average predicted and observed risk = -0.060044997475624085
# number samples = 1890
# accuracy = 0.840741
# precision class 0 = 0.849384
# precision class 1 = 0.692308
# recall class 0 = 0.979342
# recall class 1 = 0.211144
# false negative rate = 0.788856
# false positive rate = 0.020658
# positive prediction rate = 0.055026
# AUC of ROC = 0.840754
# AUC of PRC = 0.565957
# min(+P, Se) = 0.523256
#
# -------------------------------
#
# confusion matrix:
# [[230   7]
#  [ 37  17]]
#
# stratified metric for:
# demographic variable: Insurance
# value: Medicaid
#
# overall metrics:
# prevalence of IHM = 0.185567
# average predicted risk of IHM = 0.1364399939775467
# difference in average predicted and observed risk = -0.04912700602245332
# number samples = 291
# accuracy = 0.848797
# precision class 0 = 0.861423
# precision class 1 = 0.708333
# recall class 0 = 0.970464
# recall class 1 = 0.314815
# false negative rate = 0.685185
# false positive rate = 0.029536
# positive prediction rate = 0.082474
# AUC of ROC = 0.813955
# AUC of PRC = 0.487815
# min(+P, Se) = 0.537037
#
# -------------------------------
#
# confusion matrix:
# [[89  1]
#  [11  4]]
#
# stratified metric for:
# demographic variable: Insurance
# value: Government
#
# overall metrics:
# prevalence of IHM = 0.142857
# average predicted risk of IHM = 0.09978900104761124
# difference in average predicted and observed risk = -0.043067998952388775
# number samples = 105
# accuracy = 0.885714
# precision class 0 = 0.89
# precision class 1 = 0.8
# recall class 0 = 0.988889
# recall class 1 = 0.266667
# false negative rate = 0.733333
# false positive rate = 0.011111
# positive prediction rate = 0.047619
# AUC of ROC = 0.92
# AUC of PRC = 0.581837
# min(+P, Se) = 0.666667
#
# -------------------------------
#
# confusion matrix:
# [[30  1]
#  [ 4  5]]
#
# stratified metric for:
# demographic variable: Insurance
# value: Self Pay
#
# overall metrics:
# prevalence of IHM = 0.225
# average predicted risk of IHM = 0.18518699705600739
# difference in average predicted and observed risk = -0.03981300294399262
# number samples = 40
# accuracy = 0.875
# precision class 0 = 0.882353
# precision class 1 = 0.833333
# recall class 0 = 0.967742
# recall class 1 = 0.555556
# false negative rate = 0.444444
# false positive rate = 0.032258
# positive prediction rate = 0.15
# AUC of ROC = 0.956989
# AUC of PRC = 0.852734
# min(+P, Se) = 0.8
#
# -------------------------------
#
# confusion matrix:
# [[1235   27]
#  [ 205   77]]
#
# stratified metric for:
# demographic variable: Gender
# value: F
#
# overall metrics:
# prevalence of IHM = 0.182642
# average predicted risk of IHM = 0.12690700590610504
# difference in average predicted and observed risk = -0.05573499409389496
# number samples = 1544
# accuracy = 0.849741
# precision class 0 = 0.857639
# precision class 1 = 0.740385
# recall class 0 = 0.978605
# recall class 1 = 0.27305
# false negative rate = 0.72695
# false positive rate = 0.021395
# positive prediction rate = 0.067358
# AUC of ROC = 0.856214
# AUC of PRC = 0.607177
# min(+P, Se) = 0.560284
#
# -------------------------------
#
# confusion matrix:
# [[1568   32]
#  [ 269   76]]
#
# stratified metric for:
# demographic variable: Gender
# value: M
#
# overall metrics:
# prevalence of IHM = 0.177378
# average predicted risk of IHM = 0.11377599835395813
# difference in average predicted and observed risk = -0.06360200164604188
# number samples = 1945
# accuracy = 0.845244
# precision class 0 = 0.853566
# precision class 1 = 0.703704
# recall class 0 = 0.98
# recall class 1 = 0.22029
# false negative rate = 0.77971
# false positive rate = 0.02
# positive prediction rate = 0.055527
# AUC of ROC = 0.862014
# AUC of PRC = 0.594175
# min(+P, Se) = 0.58
#
# -------------------------------
#
# confusion matrix:
# [[367   9]
#  [ 85  31]]
#
# stratified metric for:
# demographic variable: Ethnicity
# value: OTHER
#
# overall metrics:
# prevalence of IHM = 0.235772
# average predicted risk of IHM = 0.13818299770355225
# difference in average predicted and observed risk = -0.09758900229644776
# number samples = 492
# accuracy = 0.808943
# precision class 0 = 0.811947
# precision class 1 = 0.775
# recall class 0 = 0.976064
# recall class 1 = 0.267241
# false negative rate = 0.732759
# false positive rate = 0.023936
# positive prediction rate = 0.081301
# AUC of ROC = 0.884928
# AUC of PRC = 0.708718
# min(+P, Se) = 0.691057
#
# -------------------------------
#
# confusion matrix:
# [[98  4]
#  [ 9  6]]
#
# stratified metric for:
# demographic variable: Ethnicity
# value: HISPANIC
#
# overall metrics:
# prevalence of IHM = 0.128205
# average predicted risk of IHM = 0.1293720006942749
# difference in average predicted and observed risk = 0.001167000694274889
# number samples = 117
# accuracy = 0.888889
# precision class 0 = 0.915888
# precision class 1 = 0.6
# recall class 0 = 0.960784
# recall class 1 = 0.4
# false negative rate = 0.6
# false positive rate = 0.039216
# positive prediction rate = 0.08547
# AUC of ROC = 0.920261
# AUC of PRC = 0.69263
# min(+P, Se) = 0.6
#
# -------------------------------
#
# confusion matrix:
# [[2030   38]
#  [ 327  108]]
#
# stratified metric for:
# demographic variable: Ethnicity
# value: WHITE
#
# overall metrics:
# prevalence of IHM = 0.173791
# average predicted risk of IHM = 0.11687400192022324
# difference in average predicted and observed risk = -0.056916998079776765
# number samples = 2503
# accuracy = 0.854175
# precision class 0 = 0.861264
# precision class 1 = 0.739726
# recall class 0 = 0.981625
# recall class 1 = 0.248276
# false negative rate = 0.751724
# false positive rate = 0.018375
# positive prediction rate = 0.05833
# AUC of ROC = 0.857273
# AUC of PRC = 0.586848
# min(+P, Se) = 0.537079
#
# -------------------------------
#
# confusion matrix:
# [[258   4]
#  [ 41   5]]
#
# stratified metric for:
# demographic variable: Ethnicity
# value: BLACK
#
# overall metrics:
# prevalence of IHM = 0.149351
# average predicted risk of IHM = 0.09421499818563461
# difference in average predicted and observed risk = -0.0551360018143654
# number samples = 308
# accuracy = 0.853896
# precision class 0 = 0.862876
# precision class 1 = 0.555556
# recall class 0 = 0.984733
# recall class 1 = 0.108696
# false negative rate = 0.891304
# false positive rate = 0.015267
# positive prediction rate = 0.029221
# AUC of ROC = 0.801112
# AUC of PRC = 0.429412
# min(+P, Se) = 0.430769
#
# -------------------------------
#
# confusion matrix:
# [[50  4]
#  [12  3]]
#
# stratified metric for:
# demographic variable: Ethnicity
# value: ASIAN
#
# overall metrics:
# prevalence of IHM = 0.217391
# average predicted risk of IHM = 0.18203400075435638
# difference in average predicted and observed risk = -0.03535699924564362
# number samples = 69
# accuracy = 0.768116
# precision class 0 = 0.806452
# precision class 1 = 0.428571
# recall class 0 = 0.925926
# recall class 1 = 0.2
# false negative rate = 0.8
# false positive rate = 0.074074
# positive prediction rate = 0.101449
# AUC of ROC = 0.818519
# AUC of PRC = 0.529967
# min(+P, Se) = 0.578947
#
# -------------------------------
#
# confusion matrix:
# [[937  18]
#  [153  55]]
#
# stratified metric for:
# demographic variable: binaryIns
# value: Private
#
# overall metrics:
# prevalence of IHM = 0.178848
# average predicted risk of IHM = 0.1136149987578392
# difference in average predicted and observed risk = -0.0652330012421608
# number samples = 1163
# accuracy = 0.852966
# precision class 0 = 0.859633
# precision class 1 = 0.753425
# recall class 0 = 0.981152
# recall class 1 = 0.264423
# false negative rate = 0.735577
# false positive rate = 0.018848
# positive prediction rate = 0.062769
# AUC of ROC = 0.891054
# AUC of PRC = 0.672552
# min(+P, Se) = 0.629808
#
# -------------------------------
#
# confusion matrix:
# [[1836   40]
#  [ 317   93]]
#
# stratified metric for:
# demographic variable: binaryIns
# value: Public
#
# overall metrics:
# prevalence of IHM = 0.179353
# average predicted risk of IHM = 0.12147700041532516
# difference in average predicted and observed risk = -0.05787599958467485
# number samples = 2286
# accuracy = 0.843832
# precision class 0 = 0.852764
# precision class 1 = 0.699248
# recall class 0 = 0.978678
# recall class 1 = 0.226829
# false negative rate = 0.773171
# false positive rate = 0.021322
# positive prediction rate = 0.05818
# AUC of ROC = 0.839387
# AUC of PRC = 0.554812
# min(+P, Se) = 0.519324
#
# -------------------------------
#
# confusion matrix:
# [[30  1]
#  [ 4  5]]
#
# stratified metric for:
# demographic variable: binaryIns
# value: Selfpay
#
# overall metrics:
# prevalence of IHM = 0.225
# average predicted risk of IHM = 0.18518699705600739
# difference in average predicted and observed risk = -0.03981300294399262
# number samples = 40
# accuracy = 0.875
# precision class 0 = 0.882353
# precision class 1 = 0.833333
# recall class 0 = 0.967742
# recall class 1 = 0.555556
# false negative rate = 0.444444
# false positive rate = 0.032258
# positive prediction rate = 0.15
# AUC of ROC = 0.956989
# AUC of PRC = 0.852734
# min(+P, Se) = 0.8
#
# -------------------------------
#
# confusion matrix:
# [[2803   59]
#  [ 474  153]]
# prevalence of IHM = 0.179708
# average predicted risk of IHM = 0.1195869967341423
# difference in average predicted and observed risk = -0.0601210032658577
# number samples = 3489
# accuracy = 0.847234
# precision class 0 = 0.855356
# precision class 1 = 0.721698
# recall class 0 = 0.979385
# recall class 1 = 0.244019
# false negative rate = 0.755981
# false positive rate = 0.020615
# positive prediction rate = 0.060762
# AUC of ROC = 0.859201
# AUC of PRC = 0.599486
# min(+P, Se) = 0.560938
#
# -------------------------------

# %% [markdown]
# ## C) Evaluate test predictions

# %%
# %run models/evaluation/evaluate_ihm.py 'models/outputs/mimic/predictions/results/TEST.2020-06-19_10-23.k_clstms.NONE.csv' \
--test_listfile 'data/mimic/aug/mortality/INSURANCE_test_listfile.csv' --output_dir 'models/outputs/mimic/predictions/confvals' --stratify
# Out:
# Saving the results in models/outputs/mimic/predictions/confvals/2020-06-19_10-46.stratified_ihm_results.json ...

# %%
# %run models/evaluation/evaluate_ihm.py 'models/outputs/mimic/predictions/results/TEST.2020-06-19_10-23.k_clstms.NONE.csv' \
--test_listfile 'data/mimic/aug/mortality/INSURANCE_test_listfile.csv' --output_dir 'models/outputs/mimic/predictions/confvals'
# Out:
# Saving the results in models/outputs/mimic/predictions/confvals/2020-06-19_11-2.nonstratified_ihm_results.json ...
